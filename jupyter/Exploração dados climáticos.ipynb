# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

weather_data = pd.read_csv("../../../Análise de Dados/Conjunto de Dados/building-data-genome-project-2/data/weather/weather.csv", index_col='timestamp', parse_dates=True)

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 331166 entries, 2016-01-01 00:00:00 to 2017-12-31 23:00:00
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   site_id         331166 non-null  object
#  1   airTemperature  331038 non-null  float64
#  2   cloudCoverage   160179 non-null  float64
#  3   dewTemperature  330838 non-null  float64
#  4   precipDepth1HR  197980 non-null  float64
#  5   precipDepth6HR  18162 non-null   float64
#  6   seaLvlPressure  309542 non-null  float64
#  7   windDirection   318161 non-null  float64
#  8   windSpeed       330592 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 25.3+ MB

# %%
weather_data[weather_data['site_id']=='Panther']
# Out:
#                      site_id  airTemperature  cloudCoverage  dewTemperature  \
# timestamp
# 2016-01-01 00:00:00  Panther            19.4            NaN            19.4
# 2016-01-01 01:00:00  Panther            21.1            6.0            21.1
# 2016-01-01 02:00:00  Panther            21.1            NaN            21.1
# 2016-01-01 03:00:00  Panther            20.6            NaN            20.0
# 2016-01-01 04:00:00  Panther            21.1            NaN            20.6
# ...                      ...             ...            ...             ...
# 2017-12-31 19:00:00  Panther            16.1            NaN             9.4
# 2017-12-31 20:00:00  Panther            16.1            4.0            10.0
# 2017-12-31 21:00:00  Panther            15.0            NaN            10.0
# 2017-12-31 22:00:00  Panther            14.4            NaN             9.4
# 2017-12-31 23:00:00  Panther            13.9            NaN            10.0
#
#                      precipDepth1HR  precipDepth6HR  seaLvlPressure  \
# timestamp
# 2016-01-01 00:00:00             0.0             NaN             NaN
# 2016-01-01 01:00:00            -1.0             NaN          1019.4
# 2016-01-01 02:00:00             0.0             NaN          1018.8
# 2016-01-01 03:00:00             0.0             NaN          1018.1
# 2016-01-01 04:00:00             0.0             NaN          1019.0
# ...                             ...             ...             ...
# 2017-12-31 19:00:00             NaN             NaN          1020.3
# 2017-12-31 20:00:00             0.0             NaN          1020.6
# 2017-12-31 21:00:00             0.0             NaN          1020.8
# 2017-12-31 22:00:00             0.0             NaN          1020.7
# 2017-12-31 23:00:00             0.0             NaN          1020.8
#
#                      windDirection  windSpeed
# timestamp
# 2016-01-01 00:00:00            0.0        0.0
# 2016-01-01 01:00:00            0.0        0.0
# 2016-01-01 02:00:00          210.0        1.5
# 2016-01-01 03:00:00            0.0        0.0
# 2016-01-01 04:00:00          290.0        1.5
# ...                            ...        ...
# 2017-12-31 19:00:00            0.0        0.0
# 2017-12-31 20:00:00          110.0        3.1
# 2017-12-31 21:00:00          130.0        3.6
# 2017-12-31 22:00:00           80.0        2.1
# 2017-12-31 23:00:00          160.0        2.1
#
# [17544 rows x 9 columns]

# %%
weather_data['site_id'].unique()
# Out:
# array(['Panther', 'Robin', 'Fox', 'Rat', 'Bear', 'Lamb', 'Peacock',
#        'Moose', 'Gator', 'Bull', 'Bobcat', 'Crow', 'Shrew', 'Swan',
#        'Wolf', 'Hog', 'Eagle', 'Cockatoo', 'Mouse'], dtype=object)

# %%
weather_data['airTemperature'].plot(figsize=(16, 12))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
weather_data_nogaps = weather_data.fillna(method='ffill')

# %%
weather_data_nogaps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 331166 entries, 2016-01-01 00:00:00 to 2017-12-31 23:00:00
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   site_id         331166 non-null  object
#  1   airTemperature  331166 non-null  float64
#  2   cloudCoverage   331165 non-null  float64
#  3   dewTemperature  331166 non-null  float64
#  4   precipDepth1HR  331166 non-null  float64
#  5   precipDepth6HR  331159 non-null  float64
#  6   seaLvlPressure  331165 non-null  float64
#  7   windDirection   331166 non-null  float64
#  8   windSpeed       331166 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 25.3+ MB

# %%
weather_data_nogaps['airTemperature'].plot(figsize=(16, 12))
# Out:
# <AxesSubplot:xlabel='timestamp'>
